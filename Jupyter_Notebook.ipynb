# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# Exercise 2 - Create a markdown cell with the title of the notebook. (1 point)
# # Notebook Title: Introduction to Data Science

# %% [markdown]
# Exercise 3 - Create a markdown cell for an introduction
# ## Introduction
# This notebook provides an overview of fundamental concepts in data science, including programming languages, libraries, tools, and practical examples.

# %% [markdown]
# Exercise 4 - Create a markdown cell to list data science languages.
# ## Data Science Programming Languages
# - Python
# - R
# - SQL
# - Julia
# - Scala

# %% [markdown]
# Exercise 5 - Create a markdown cell to list data science libraries
#
# ## Data Science Libraries
# - Pandas
# - NumPy
# - Matplotlib
# - Scikit-learn
# - TensorFlow
# - Keras

# %% [markdown]
# Exercise 6 - Create a markdown cell with a table of Data Science tools
# ## Data Science Tools
#
# | Tool             | Description                                            |
# |------------------|--------------------------------------------------------|
# | Jupyter Notebook | Interactive environment for writing and executing code.|
# | Anaconda         | Python distribution with pre-installed packages.       |
# | RStudio          | IDE for R.                                             |
# | Tableau          | Data visualization tool.                               |
# | Apache Hadoop    | Framework for processing large datasets.               |
# | Apache Spark     | Fast data analytics engine.                            |

# %% [markdown]
# Exercise 7 - Create a markdown cell introducing examples of arithmetic expressions.
# ## Examples of Arithmetic Expressions
# Below are some examples of basic arithmetic expressions in Python:

# %% [markdown]
# Exercise 8 - Create a code cell to multiply and add numbers.
# # Multiplication and addition of numbers

# %%
a = 6
b = 7
multiplication = a * b
sum_ = a + b

print(f"Multiplication: {multiplication}")
print(f"Sum: {sum_}")

# %% [markdown]
# Exercise 9 - Create a code cell to convert minutes to hours.

# %%
# Conversion of minutes to hours
minutes = 150
hours = minutes / 60

print(f"{minutes} minutes are {hours} hours")

# %% [markdown]
# Exercise 10 - Insert a code cell to list Objectives. (3 points)

# %%
# List of Objectives
objectives = [
    "Understand the fundamentals of data science",
    "Learn to use key programming languages and libraries",
    "Familiarize with data science tools",
    "Perform data analysis and visualize results",
    "Apply machine learning techniques in real projects"
]

for objective in objectives:
    print(f"- {objective}")

# %% [markdown]
# Exercise 11 - Create a markdown cell to indicate the author's name. (2 points)

# %% [markdown]
# ## Author
# Author's Name: Claudio Chavarria

# %% [markdown]
#  Share your notebook via GitHub (3 points)

# %% [markdown]
# **Repository link:** [https://github.com/username/repository](https://github.com/username/repository)

# %% [markdown]
# Exercise 13 - Take a screenshot of the first page of the notebook. (1 point)
